# %%
### bolsas do prouni oferecidas em SJC - 2018

# %%
import pandas as pd

# %%
dataset = pd.read_csv('cursosprouni.csv', sep=',')

# %%
### só verificar se o arquivo está ok...

# %%
dataset.head()
# Out:
#   uf_busca         cidade_busca  \
# 0       SP  Sao Jose dos Campos
# 1       SP  Sao Jose dos Campos
# 2       SP  Sao Jose dos Campos
# 3       SP  Sao Jose dos Campos
# 4       SP  Sao Jose dos Campos
#
#                                    universidade_nome  \
# 0  Centro Universitário Internacional - Uninter -...
# 1  Escola Superior de Administração de Empresas -...
# 2  Faculdade de Tecnologia de São José dos Campos...
# 3  Faculdade de Tecnologia de São José dos Campos...
# 4               Faculdade Educacional da Lapa - FAEL
#
#                                          campus_nome           nome  \
# 0        PAP SÃO JOSÉ DOS CAMPOS (ITS) - Vila Adyana  Administração
# 1                                    CENTRO - Centro  Administração
# 2                  ETEP ESPLANADA - Jardim Esplanada  Administração
# 3                  ETEP ESPLANADA - Jardim Esplanada  Administração
# 4  SP - SÃO JOSÉ DOS CAMPOS - POLO EAD - Vila Igu...  Administração
#
# ...

# %%
### bolsas disponíveis para os seguintes cursos

# %%
dataset['nome'].unique()
# Out:
# array(['Administração', 'Análise e Desenvolvimento de Sistemas',
#        'Arquitetura e Urbanismo', 'Artes VIsuais', 'Banco de Dados',
#        'Biblioteconomia', 'Biomedicina', 'Ciência da Computação',
#        'Ciências Biológicas', 'Ciências Contábeis', 'Ciências Econômicas',
#        'Ciências Sociais', 'Comércio Exterior', 'Computação',
#        'Comunicação Social - Publicidade e Propaganda',
#        'Comunicação Social - Radio e Televisão', 'Design de Interiores',
#        'Design de Moda', 'Design Gráfico', 'Direito', 'Educação Física',
#        'Embelezamento e Imagem Pessoal', 'Enfermagem',
#        'Engenharia Aeronáutica', 'Engenharia Aeronáutica e Espaço',
#        'Engenharia Ambiental', 'Engenharia Ambiental e Sanitária',
#        'Engenharia Automotiva', 'Engenharia Biomédica',
#        'Engenharia Civil', 'Engenharia da Computação',
#        'Engenharia de Computação', 'Engenharia de Controle e Automação',
# ...

# %%
### quantidades de instituições para possível candidatura por curso

# %%
dataset["nome"].value_counts()
# Out:
# Logística                                        11
# Educação Física                                  10
# Administração                                    10
# Gestão de Recursos Humanos                       10
# Pedagogia                                         9
# Ciências Contábeis                                9
# Análise e Desenvolvimento de Sistemas             8
# Ciências Biológicas                               7
# Gestão Financeira                                 7
# Artes VIsuais                                     6
# Matemática                                        6
# Serviço Social                                    5
# Marketing                                         5
# Engenharia de Produção                            5
# Engenharia Civil                                  5
# Processos Gerenciais                              5
# Enfermagem                                        5
# Psicologia                                        5
# ...

# %%
### quantidade de bolsas integrais oferecidas por curso

# %%
dataset.groupby("nome").mean()["bolsa_integral_ampla"].sort_values()
# Out:
# nome
# Gestão Ambiental                                 1.000000
# Engenharia Ambiental                             1.000000
# Gestão da Tecnologia da Informação               1.000000
# Matemática                                       1.000000
# Engenharia Elétrica                              1.000000
# Letras - Português e Inglês                      1.000000
# Letras - Português e Espanhol                    1.000000
# Engenharia de Controle e Automação               1.000000
# Letras - Português                               1.000000
# Negócios Imobiliários                            1.000000
# Letras - Inglês                                  1.000000
# Jornalismo                                       1.000000
# Filosofia                                        1.000000
# Gestão de Turismo                                1.000000
# Gestão de Serviços Jurídicos e Notariais         1.000000
# Geografia                                        1.000000
# ...

# %%
### notas de corte por curso

# %%
dataset.groupby("nome").mean()["nota_integral_ampla"].sort_values()
# Out:
# nome
# Negócios Imobiliários                            499.700000
# Gestão de Segurança Privada                      511.160000
# Petróleo e Gás                                   513.140000
# Processos Gerenciais                             523.670000
# Gestão da Produção Industrial                    528.446667
# Sistemas para Internet                           531.740000
# Gestão Hospitalar                                531.740000
# Teologia                                         532.420000
# Gestão da Tecnologia da Informação               540.040000
# Logística                                        540.544000
# Letras - Português                               542.560000
# Computação                                       542.760000
# Gestão de Turismo                                547.200000
# Engenharia Ambiental                             550.100000
# Gestão Financeira                                555.840000
# Pedagogia                                        556.451111
# ...

# %%
### todos os dados de determinado curso/instituição

# %%
dataset.loc[2]
# Out:
# uf_busca                                                               SP
# cidade_busca                                          Sao Jose dos Campos
# universidade_nome       Faculdade de Tecnologia de São José dos Campos...
# campus_nome                             ETEP ESPLANADA - Jardim Esplanada
# nome                                                        Administração
# grau                                                          Bacharelado
# turno                                                            Matutino
# mensalidade                                                           599
# bolsa_integral_cotas                                                    2
# bolsa_integral_ampla                                                    3
# bolsa_parcial_cotas                                                   NaN
# bolsa_parcial_ampla                                                   NaN
# nota_integral_ampla                                                598.48
# ...

# %%
### mensalidade (apenas para informação de quanto seria se não fosse bolsista!)

# %%
dataset.groupby("nome").mean()["mensalidade"].sort_values()
# Out:
# nome
# Sociologia                                        149.000000
# Negócios Imobiliários                             159.000000
# Embelezamento e Imagem Pessoal                    209.000000
# Gestão Comercial                                  211.000000
# Física                                            235.730000
# Ciências Sociais                                  235.730000
# Gestão de Serviços Jurídicos e Notariais          248.000000
# Gestão de Turismo                                 249.000000
# Secretariado                                      255.095000
# Banco de Dados                                    257.190000
# Segurança no Trabalho                             257.190000
# Gestão do Agronegócio                             257.190000
# Processos Gerenciais                              272.038000
# Filosofia                                         273.047500
# Gestão Pública                                    274.000000
# ...
